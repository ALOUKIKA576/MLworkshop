# %% [markdown]
# <a href="https://colab.research.google.com/github/ALOUKIKA576/MLworkshop/blob/main/Crop_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d50bf49-7f00-4949-bb98-b796cd8cd83d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d50bf49-7f00-4949-bb98-b796cd8cd83d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Crop_recommendation.csv')

# %%
print(df)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
print(df.head())
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
print(df.tail())
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
print(df.shape)
# Out:
# (2200, 8)

# %%
print(df.columns)
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB
# None

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['temperature'],df['label'])
plt.xlabel('Temperature')
plt.ylabel('Label')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.scatterplot(x='humidity',y='label',data=df,hue='label',palette='Set2')
plt.title('Humidity vs Label')
plt.xlabel('Humidity')
plt.ylabel('Label')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['label']=le.fit_transform(df['label'])

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536     20
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537     20
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248     20
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034     20
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340     20
# ...   ...  ..  ..          ...        ...       ...         ...    ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507      5
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610      5
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839      5
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293      5
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041      5
#
# [2200 rows x 8 columns]

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
y
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 2195     5
# 2196     5
# 2197     5
# 2198     5
# 2199     5
# Name: label, Length: 2200, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266646,
#          0.04330173,  1.8103605 ],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705125,
#          0.73487256,  2.24205791],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.48695381,
#          1.77151047,  2.92106603],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123516,
#         -0.13812031,  1.27141766],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951801,
#          0.37390383,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802006,
#          0.40109573,  0.68200518]])

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536     20
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537     20
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248     20
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034     20
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340     20
# ...   ...  ..  ..          ...        ...       ...         ...    ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507      5
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610      5
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839      5
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293      5
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041      5
#
# [2200 rows x 8 columns]

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
model=lr.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([15, 21, 17, 17,  0, 12,  0, 13, 14, 10,  2,  4, 19,  8,  4, 19,  0,
#        11, 17, 15,  5, 17, 16, 17,  3,  8, 14, 16, 18, 20, 19, 13,  8, 10,
#         8,  2,  8,  3,  3,  9, 17, 12,  2, 11, 14, 11, 18,  4, 15, 11,  2,
#         5,  7, 14,  5,  9,  6,  0,  1, 10, 21,  4, 10, 16, 17,  2, 16, 20,
#        15, 18, 15,  4,  8,  1,  2, 17,  1,  6, 21, 16,  5,  3,  8, 13, 16,
#        12,  5, 13,  2, 19, 11, 13,  6, 17, 18, 13,  9,  5,  2, 10,  4,  8,
#        16, 15, 21,  9, 21,  1, 18, 13,  1,  8,  6, 19, 18,  3, 11,  4, 19,
#        20, 18,  7,  2,  4,  3,  2,  4, 11,  1, 13,  1,  9, 19,  3,  4, 16,
#        18,  1,  1,  0,  9, 15, 14, 13,  4,  6,  0,  4,  9, 18, 14, 10, 21,
#        14, 18, 18, 18,  9, 11,  8,  3,  0, 16,  6, 20,  4,  7, 10, 21,  7,
#         7,  2, 19,  3,  4, 11, 10,  7, 21,  8,  5,  5,  9,  8, 13,  9,  1,
#         9,  4, 17, 17, 14, 12, 19, 21, 18, 11,  0,  2,  3,  7,  7,  1,  6,
# ...

# %%
y_test
# Out:
# 1451    15
# 1334    21
# 1761    17
# 1735    17
# 1576     0
#         ..
# 59      20
# 71      20
# 1908     6
# 1958     6
# 482     18
# Name: label, Length: 440, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9636363636363636

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
#lr=LogisticRegression()
model1=dt.fit(x_train,y_train)

# %%
y_pred1=model1.predict(x_test)

# %%
accuracy_score(y_pred1,y_test)
# Out:
# 0.9863636363636363

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
model3=rf.fit(x_train,y_train)

# %%
Y_pred3=model3.predict(x_test)

# %%
accuracy_score(Y_pred3,y_test)
# Out:
# 0.9931818181818182

# %%
df.sample(5)
# Out:
#         N    P    K  temperature   humidity        ph    rainfall  label
# 1601   37    6   13    26.030973  91.508193  7.511755  101.284774     16
# 914    29   22   40    23.626002  89.732667  6.145104  107.683687     19
# 1297    6  142  202    27.237083  82.945733  6.224543   70.425089      7
# 1364  115   11   46    24.415927  89.396555  6.623167   40.321619     21
# 1862   17   30   27    29.030650  90.790939  5.894027  205.572037      4

# %%
model.predict([[38,62,25,32.747739,67.779546,7.453975,63.377844		]])
# Out:
# array([17])

# %%
x[45]
# Out:
# array([ 1.0958911 , -0.55681099, -0.20043066, -0.14201436,  0.40631577,
#        -0.43319904,  1.45990275])

# %%
y[45]
# Out:
# np.int64(20)

# %%
model.predict([[ 1.0958911 , -0.55681099, -0.20043066, -0.14201436,  0.40631577,
       -0.43319904,  1.45990275]])
# Out:
# array([8])

# %%
x[2000]
# Out:
# array([ 1.04170369, -0.19293629, -0.20043066, -0.01808443,  0.03444619,
#        -0.60348703,  0.88129132])

# %%
model.predict([[ 1.04170369, -0.19293629, -0.20043066, -0.01808443,  0.03444619,
       -0.60348703,  0.88129132]])
# Out:
# array([8])

# %%
y[2000]
# Out:
# np.int64(8)
